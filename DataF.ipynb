# %%
import numpy as np
import pandas as pd
arr={'Name':['Jack','Riti','Tom','Neelu','John','Mike'],
    'Age':[34,30,31,32,16,17],
      'City':['Sydeny','Delhi','Mumbai','Banglore','New York','las vegas'],
      'Country':['Australia','India','India','India','US','US'],
      'Course':['Computer science','Computer science','Computer science','Computer science','Computer science','Computer science'],
      'Grade':['A','A','A','A','A','A']}
pd.DataFrame(arr)
# Out:
#     Name  Age       City    Country            Course Grade
# 0   Jack   34     Sydeny  Australia  Computer science     A
# 1   Riti   30      Delhi      India  Computer science     A
# 2    Tom   31     Mumbai      India  Computer science     A
# 3  Neelu   32   Banglore      India  Computer science     A
# 4   John   16   New York         US  Computer science     A
# 5   Mike   17  las vegas         US  Computer science     A

# %%
df=pd.DataFrame(arr,index=['a','b','c','d','e','f'])
df
# Out:
#     Name  Age       City    Country            Course Grade
# a   Jack   34     Sydeny  Australia  Computer science     A
# b   Riti   30      Delhi      India  Computer science     A
# c    Tom   31     Mumbai      India  Computer science     A
# d  Neelu   32   Banglore      India  Computer science     A
# e   John   16   New York         US  Computer science     A
# f   Mike   17  las vegas         US  Computer science     A

# %%
df.shape
# Out:
# (6, 6)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Course', 'Grade'], dtype='object')

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.query('Country=="US"')
# Out:
#    Nmae  Age       City Country            Course Grade
# e  John   16   New York      US  Computer science     A
# f  Mike   17  las vegas      US  Computer science     A

# %%
df.query('Age>=30')
# Out:
#     Name  Age      City    Country            Course Grade
# a   Jack   34    Sydeny  Australia  Computer science     A
# b   Riti   30     Delhi      India  Computer science     A
# c    Tom   31    Mumbai      India  Computer science     A
# d  Neelu   32  Banglore      India  Computer science     A

# %%
df[df.Name.str.startswith('J')]
# Out:
#    Name  Age      City    Country            Course Grade
# a  Jack   34    Sydeny  Australia  Computer science     A
# e  John   16  New York         US  Computer science     A

# %%
d= { 'Name': ['Avery Bradley', 'John Holland', 'Jonas Jerebko', 'Jordan Mickey', 'Terry Rozier', 'Jared sullinger', 'Evan Turner'],
    'Team': ['Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics', 'Boston Celtics'],
    'Number': [0.0, 30.0, 8.0, np.nan, 12.0, 7.0, 11.0],
    'Position': ['PG', 'SG', 'PF', 'PF', 'PG', 'C', 'SG'],
    'Age': [25,27,29,21,22,np.nan,27] }
d=pd.DataFrame(d)
d
# Out:
#               Name            Team  Number Position   Age
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1     John Holland  Boston Celtics    30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtics     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jared sullinger  Boston Celtics     7.0        C   NaN
# 6      Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
pd.DataFrame(d,index=[0,2,6])
# Out:
#             Name            Team  Number Position   Age
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0
# 2  Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 6    Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
pd.DataFrame(d,columns=['Name','Number','Age'])
# Out:
#               Name  Number   Age
# 0    Avery Bradley     0.0  25.0
# 1     John Holland    30.0  27.0
# 2    Jonas Jerebko     8.0  29.0
# 3    Jordan Mickey     NaN  21.0
# 4     Terry Rozier    12.0  22.0
# 5  Jared sullinger     7.0   NaN
# 6      Evan Turner    11.0  27.0

# %%
d.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, 'PG', 25.0],
#        ['John Holland', 'Boston Celtics', 30.0, 'SG', 27.0],
#        ['Jonas Jerebko', 'Boston Celtics', 8.0, 'PF', 29.0],
#        ['Jordan Mickey', 'Boston Celtics', nan, 'PF', 21.0],
#        ['Terry Rozier', 'Boston Celtics', 12.0, 'PG', 22.0],
#        ['Jared sullinger', 'Boston Celtics', 7.0, 'C', nan],
#        ['Evan Turner', 'Boston Celtics', 11.0, 'SG', 27.0]], dtype=object)

# %%
d.shape
# Out:
# (7, 5)

# %%
d['Number'].value_counts()
# Out:
# Number
# 0.0     1
# 30.0    1
# 8.0     1
# 12.0    1
# 7.0     1
# 11.0    1
# Name: count, dtype: int64

# %%
d.query('(Team=="Boston Celtics") and (Number>=8.0)')
# Out:
#             Name            Team  Number Position   Age
# 1   John Holland  Boston Celtics    30.0       SG  27.0
# 2  Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# 4   Terry Rozier  Boston Celtics    12.0       PG  22.0
# 6    Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
d[(len(d)//2):].head(5)#enter of the actual records
# Out:
#               Name            Team  Number Position   Age
# 3    Jordan Mickey  Boston Celtics     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jared sullinger  Boston Celtics     7.0        C   NaN
# 6      Evan Turner  Boston Celtics    11.0       SG  27.0
